# %% [markdown]
# <a href="https://colab.research.google.com/github/odumjennifer-eng/Cambridge-PhD---Glaucoma/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("welcome Jennifer to your first line of code")
# Out:
# welcome Jennifer to your first line of code

# %%
print (82 + 27)
# Out:
# 109

# %%
# create variable called test_cal and give it a value of 82+27
test_cal = 82 + 27

# print the value of test_cal
print (test_cal)
# Out:
# 109

# %%
# change value of variable
test_cal = 3 + 10
print (test_cal)
# Out:
# 13

# %%
# increase the value by 10
test_cal = test_cal + 10

#print value increase
print (test_cal)
# Out:
# 23

# %%
# create variable
num_icecream = 55
num_days = 8
num_people = 16

# calculate how much ice cream each person ate per day across 8 days
icecream_per_person = num_icecream / num_days / num_people
print (icecream_per_person)
# Out:
# 0.4296875

# %%
#update num_days to 1
num_days = 1

icecream_per_person = num_icecream / num_days / num_people
print (icecream_per_person)
# Out:
# 3.4375
